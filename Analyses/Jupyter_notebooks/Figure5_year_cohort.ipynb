# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
from pywaffle import Waffle

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 8))

# Combine duplicate rows by summing their values
# This is needed because the data breaks out some additional categories that we are not interested in
data_combined = data.groupby(level=[0, 1]).sum()


# colors_list = ['#EC4E20', 
#         '#F2805F',
#         '#FCCCBE',
#         '#016FB9',
#         '#6BAFDC',
#         '#218380',
#         '#57ABA9',
#         '#8CD4D1', 
#         '#C2FCFA',
#         '#51514B',
#         '#A3A39A']

colors_list = ['#EC4E20', #flame orginal
        '#F69A7F', #flame light
        '#FCCCBE', #flame lightest
        '#FF9505', #orange original
        '#FFC474', #orange light
        '#016FB9', #azul original
        '#4799D0', #azul light
        '#8EC4E8', #azul lighter
        '#D4EEFF', #azul lightest
        '#57ABA9', #teal light
        '#C2FCFA'] #teal lightest

#print([f"{k} ({v})" for k, v in data['New association'].items()][0:3])

fig = plt.figure(
    FigureClass=Waffle,
    plots={
        411: {
            'values': data_combined.loc[('Gene-disease Associations'),'All'],
            'colors': colors_list[0:3],
            #'title': {'label': 'Gene-disease associations', 'loc': 'left', 'fontsize': 12}
        },
        412: {
            'values': data_combined.loc[('Variant Reclassifications'),'All'],
            'colors': colors_list[3:5],
            #'title': {'label': 'Variant reclassifications', 'loc': 'left', 'fontsize': 12}
        },
        413: {
            'values': data_combined.loc[('Missed in Manual Analysis'),'All'],
            'colors': colors_list[5:9],
            #'title': {'label': 'Missed in original analysis', 'loc': 'left', 'fontsize': 12}
        },
        414: {
            'values': data_combined.loc[('CNV/SV'),'All'],
            'colors': colors_list[9:12],
            #'title': {'label': 'CNV/SV', 'loc': 'left', 'fontsize': 12}
        },
    },
    rows=5,
    #colors=colors_list,
    rounding_rule='ceil',
    figsize=(5, 5)
)

# import matplotlib.patches as mpatches
# import matplotlib.pyplot as plt

# patches = []
# for x in range(len(solve_data)):
#     patches.append(mpatches.Patch(color=colors_list[x], label=list(solve_data.keys())[x]))
# plt.legend(handles=patches, bbox_to_anchor=(3,2), loc="lower left")

# legend1 = plt.legend(handles=patches[0:3], bbox_to_anchor=(1.5,5.7), loc="upper left")
# legend2 = plt.legend(handles=patches[3:5], bbox_to_anchor=(1.5,4.3), loc="upper left")
# legend3 = plt.legend(handles=patches[5:9], bbox_to_anchor=(1.5,2.8), loc="upper left")
# legend4 = plt.legend(handles=patches[9:11], bbox_to_anchor=(1.5,1.1), loc="upper left")
# fig.add_artist(legend1)
# fig.add_artist(legend2)
# fig.add_artist(legend3)
# fig.add_artist(legend4)


fig.savefig('../../Figures/Fig5/Fig5_year_cohort.png')
# Out:
# <Waffle size 500x500 with 4 Axes>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
from pywaffle import Waffle

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
# This is needed because the data breaks out some additional categories that we are not interested in
data_combined = data.groupby(level=[0, 1]).sum()


# colors_list = ['#EC4E20', 
#         '#F2805F',
#         '#FCCCBE',
#         '#016FB9',
#         '#6BAFDC',
#         '#218380',
#         '#57ABA9',
#         '#8CD4D1', 
#         '#C2FCFA',
#         '#51514B',
#         '#A3A39A']

colors_list = ['#EC4E20', #flame orginal
        '#F69A7F', #flame light
        '#FCCCBE', #flame lightest
        '#FF9505', #orange original
        '#FFC474', #orange light
        '#016FB9', #azul original
        '#4799D0', #azul light
        '#8EC4E8', #azul lighter
        '#D4EEFF', #azul lightest
        '#57ABA9', #teal light
        '#C2FCFA'] #teal lightest

#print([f"{k} ({v})" for k, v in data['New association'].items()][0:3])

fig = plt.figure(
    FigureClass=Waffle,
    plots={
        411: {
            'values': data_combined.loc[('Gene-disease Associations'),'2019'],
            'colors': colors_list[0:3],
            #'title': {'label': 'Gene-disease associations', 'loc': 'left', 'fontsize': 12}
        },
        412: {
            'values': data_combined.loc[('Variant Reclassifications'),'2019'],
            'colors': colors_list[3:5],
            #'title': {'label': 'Variant reclassifications', 'loc': 'left', 'fontsize': 12}
        },
        413: {
            'values': data_combined.loc[('Missed in Manual Analysis'),'2019'],
            'colors': colors_list[5:9],
            #'title': {'label': 'Missed in original analysis', 'loc': 'left', 'fontsize': 12}
        },
        414: {
            'values': data_combined.loc[('CNV/SV'),'2019'],
            'colors': colors_list[9:12],
            #'title': {'label': 'CNV/SV', 'loc': 'left', 'fontsize': 12}
        },
    },
    rows=5,
    #colors=colors_list,
    rounding_rule='ceil',
    figsize=(5, 5)
)



fig.savefig('../../Figures/Fig5/Fig5_year_cohort_2019.png')
# Out:
# <Waffle size 500x500 with 4 Axes>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
from pywaffle import Waffle

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
# This is needed because the data breaks out some additional categories that we are not interested in
data_combined = data.groupby(level=[0, 1]).sum()


# colors_list = ['#EC4E20', 
#         '#F2805F',
#         '#FCCCBE',
#         '#016FB9',
#         '#6BAFDC',
#         '#218380',
#         '#57ABA9',
#         '#8CD4D1', 
#         '#C2FCFA',
#         '#51514B',
#         '#A3A39A']

colors_list = ['#EC4E20', #flame orginal
        '#F69A7F', #flame light
        '#FCCCBE', #flame lightest
        '#FF9505', #orange original
        '#FFC474', #orange light
        '#016FB9', #azul original
        '#4799D0', #azul light
        '#8EC4E8', #azul lighter
        '#D4EEFF', #azul lightest
        '#57ABA9', #teal light
        '#C2FCFA'] #teal lightest

#print([f"{k} ({v})" for k, v in data['New association'].items()][0:3])

fig = plt.figure(
    FigureClass=Waffle,
    plots={
        411: {
            'values': data_combined.loc[('Gene-disease Associations'),'2020'],
            'colors': colors_list[0:3],
            #'title': {'label': 'Gene-disease associations', 'loc': 'left', 'fontsize': 12}
        },
        412: {
            'values': data_combined.loc[('Variant Reclassifications'),'2020'],
            'colors': colors_list[3:5],
            #'title': {'label': 'Variant reclassifications', 'loc': 'left', 'fontsize': 12}
        },
        413: {
            'values': data_combined.loc[('Missed in Manual Analysis'),'2020'],
            'colors': colors_list[5:9],
            #'title': {'label': 'Missed in original analysis', 'loc': 'left', 'fontsize': 12}
        },
        414: {
            'values': data_combined.loc[('CNV/SV'),'2020'],
            'colors': colors_list[9:12],
            #'title': {'label': 'CNV/SV', 'loc': 'left', 'fontsize': 12}
        },
    },
    rows=5,
    #colors=colors_list,
    rounding_rule='ceil',
    figsize=(5, 5)
)


fig.savefig('../../Figures/Fig5/Fig5_year_cohort_2020.png')
# Out:
# <Waffle size 500x500 with 4 Axes>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
from pywaffle import Waffle

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
# This is needed because the data breaks out some additional categories that we are not interested in
data_combined = data.groupby(level=[0, 1]).sum()

# Sorting dataframe so that legends appear in the desired order
custom_sort={'Gene-disease Associations': 1, 'Variant Reclassifications': 2, 'Missed in Manual Analysis': 3, 'CNV/SV': 4}
data_sorted = data_combined.sort_index(key=lambda x: x.map(custom_sort))


colors_list = ['#EC4E20', #flame orginal
        '#F69A7F', #flame light
        '#FCCCBE', #flame lightest
        '#FF9505', #orange original
        '#FFC474', #orange light
        '#016FB9', #azul original
        '#4799D0', #azul light
        '#8EC4E8', #azul lighter
        '#D4EEFF', #azul lightest
        '#57ABA9', #teal light
        '#C2FCFA'] #teal lightest

#print([f"{k} ({v})" for k, v in data['New association'].items()][0:3])

fig = plt.figure(
    FigureClass=Waffle,
    plots={
        411: {
            'values': data_combined.loc[('Gene-disease Associations'),'2021'],
            'colors': colors_list[0:3],
            #'title': {'label': 'Gene-disease associations', 'loc': 'left', 'fontsize': 12}
        },
        412: {
            'values': data_combined.loc[('Variant Reclassifications'),'2021'],
            'colors': colors_list[3:5],
            #'title': {'label': 'Variant reclassifications', 'loc': 'left', 'fontsize': 12}
        },
        413: {
            'values': data_combined.loc[('Missed in Manual Analysis'),'2021'],
            'colors': colors_list[5:9],
            #'title': {'label': 'Missed in original analysis', 'loc': 'left', 'fontsize': 12}
        },
        414: {
            'values': data_combined.loc[('CNV/SV'),'2021'],
            'colors': colors_list[9:12],
            #'title': {'label': 'CNV/SV', 'loc': 'left', 'fontsize': 12}
        },
    },
    rows=5,
    #colors=colors_list,
    rounding_rule='ceil',
    figsize=(5, 5)
)

# import matplotlib.patches as mpatches
# import matplotlib.pyplot as plt

# patches = []
# for x in range(len(data_sorted.index.get_level_values(1))):
#     labels = list(data_sorted.index.get_level_values(1))
#     patches.append(mpatches.Patch(color=colors_list[x], label=labels[x]))
# plt.legend(handles=patches, bbox_to_anchor=(3,2), loc="lower left")

# legend1 = plt.legend(handles=patches[0:3], bbox_to_anchor=(1.5,4.3), loc="upper left")
# legend2 = plt.legend(handles=patches[3:5], bbox_to_anchor=(1.5,3.0), loc="upper left")
# legend3 = plt.legend(handles=patches[5:9], bbox_to_anchor=(1.5,2.1), loc="upper left")
# legend4 = plt.legend(handles=patches[9:11], bbox_to_anchor=(1.5,0.8), loc="upper left")
# fig.add_artist(legend1)
# fig.add_artist(legend2)
# fig.add_artist(legend3)
# fig.add_artist(legend4)

fig.savefig('../../Figures/Fig5/Fig5_year_cohort_2021.png')
# Out:
# <Waffle size 500x500 with 4 Axes>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
from pywaffle import Waffle

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
# This is needed because the data breaks out some additional categories that we are not interested in
data_combined = data.groupby(level=[0, 1]).sum()

# Sorting dataframe so that legends appear in the desired order
custom_sort={'Gene-disease Associations': 1, 'Variant Reclassifications': 2, 'Missed in Manual Analysis': 3, 'CNV/SV': 4}
data_sorted = data_combined.sort_index(key=lambda x: x.map(custom_sort))


colors_list = ['#EC4E20', #flame orginal
        '#F69A7F', #flame light
        '#FCCCBE', #flame lightest
        '#FF9505', #orange original
        '#FFC474', #orange light
        '#016FB9', #azul original
        '#4799D0', #azul light
        '#8EC4E8', #azul lighter
        '#D4EEFF', #azul lightest
        '#57ABA9', #teal light
        '#C2FCFA'] #teal lightest

#print([f"{k} ({v})" for k, v in data['New association'].items()][0:3])

fig = plt.figure(
    FigureClass=Waffle,
    plots={
        411: {
            'values': data_combined.loc[('Gene-disease Associations'),'2022'],
            'colors': colors_list[0:3],
            #'title': {'label': 'Gene-disease associations', 'loc': 'left', 'fontsize': 12}
        },
        412: {
            'values': data_combined.loc[('Variant Reclassifications'),'2022'],
            'colors': colors_list[3:5],
            #'title': {'label': 'Variant reclassifications', 'loc': 'left', 'fontsize': 12}
        },
        413: {
            'values': data_combined.loc[('Missed in Manual Analysis'),'2022'],
            'colors': colors_list[5:9],
            #'title': {'label': 'Missed in original analysis', 'loc': 'left', 'fontsize': 12}
        },
        414: {
            'values': data_combined.loc[('CNV/SV'),'2022'],
            'colors': colors_list[9:12],
            #'title': {'label': 'CNV/SV', 'loc': 'left', 'fontsize': 12}
        },
    },
    rows=5,
    #colors=colors_list,
    rounding_rule='ceil',
    figsize=(5, 5)
)

import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

patches = []
for x in range(len(data_sorted.index.get_level_values(1))):
    labels = list(data_sorted.index.get_level_values(1))
    patches.append(mpatches.Patch(color=colors_list[x], label=labels[x]))
plt.legend(handles=patches, bbox_to_anchor=(3,2), loc="lower left")

legend1 = plt.legend(handles=patches[0:3], bbox_to_anchor=(1.5,4.3), loc="upper left")
legend2 = plt.legend(handles=patches[3:5], bbox_to_anchor=(1.5,3.0), loc="upper left")
legend3 = plt.legend(handles=patches[5:9], bbox_to_anchor=(1.5,2.1), loc="upper left")
legend4 = plt.legend(handles=patches[9:11], bbox_to_anchor=(1.5,0.8), loc="upper left")
fig.add_artist(legend1)
fig.add_artist(legend2)
fig.add_artist(legend3)
fig.add_artist(legend4)

fig.savefig('../../Figures/Fig5/Fig5_year_cohort_2022.png')
# Out:
# <Waffle size 500x500 with 4 Axes>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Paths to the images
image_paths = ['../../Figures/Fig5/Fig5_year_cohort.png', '../../Figures/Fig5/Fig5_year_cohort_2019.png', '../../Figures/Fig5/Fig5_year_cohort_2020.png', '../../Figures/Fig5/Fig5_year_cohort_2021.png', '../../Figures/Fig5/Fig5_year_cohort_2022.png']

# Set the default font to Arial
plt.rcParams['font.family'] = 'Arial'

# Create a figure with three subplots arranged horizontally with variable widths
fig = plt.figure(figsize=(18, 6))

# Manually add subplots with specific positions
positions = [
    [0.25, 0.1, 0.25, 0.75],  # [left, bottom, width, height] for the first subplot
    [0.45, 0.1, 0.25, 0.75],  # Adjust the left position for the second subplot
    [0.54, 0.1, 0.25, 0.75],  # Adjust the left position for the third subplot
    [0.64, 0.1, 0.25, 0.75],  # Adjust the left position for the third subplot
    [0.72, 0.1, 0.25, 0.75]  # Adjust the left position for the third subplot
]

# Load and display the images in each subplot
for i, pos in enumerate(positions):
    ax = fig.add_axes(pos)
    img = mpimg.imread(image_paths[i])
    ax.imshow(img, aspect='equal')
    ax.axis('off')  # Turn off the axis

# Adjust layout to prevent overlap
#plt.tight_layout(rect=[0, 0, 1, 0.95]) 

# Add text that spans across subplot boundaries
fig.text(0.205, 0.86, 'New Diagnoses\n(Count)', ha='center', fontsize=12, fontweight='bold')
fig.text(0.31, 0.86, 'Full Cohort\n(238)', ha='center', fontsize=12)
fig.text(0.475, 0.85, '2019\nSub-cohort\n(71)', ha='center', fontsize=12)
fig.text(0.570, 0.85, '2020\nSub-cohort\n(64)', ha='center', fontsize=12)
fig.text(0.660, 0.85, '2021\nSub-cohort\n(46)', ha='center', fontsize=12)
fig.text(0.740, 0.85, '2022\nSub-cohort\n(47)', ha='center', fontsize=12)


fig.text(0.205, 0.73, 'Gene-disease\nAssociations', ha='center', fontsize=12)
fig.text(0.205, 0.55, 'Variant\nReclassifications', ha='center', fontsize=12)
fig.text(0.205, 0.37, 'Missed in\nManual Analysis', ha='center', fontsize=12)
fig.text(0.205, 0.195, 'CNV/SV', ha='center', fontsize=12)

fig.text(0.205, 0.04, 'Total Cohort Size\nNew Diagnosis %', ha='center', fontsize=12, fontweight='bold')
fig.text(0.31, 0.04, 'N=4744\n5.0%', ha='center', fontsize=12)
fig.text(0.4750, 0.04, 'N=879\n8.1%', ha='center', fontsize=12)
fig.text(0.570, 0.04, 'N=1071\n6.1%', ha='center', fontsize=12)
fig.text(0.660, 0.04, 'N=1321\n3.5%', ha='center', fontsize=12)
fig.text(0.740, 0.04, 'N=1236\n3.7%', ha='center', fontsize=12)



fig.savefig('../../Figures/Fig5/Fig5_year_cohort_All.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle
import matplotlib.patches as mpatches

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
data_combined = data.groupby(level=[0, 1]).sum()

# Custom sort order for the index
custom_sort = {'Gene-disease Associations': 1, 'Variant Reclassifications': 2, 'Missed in Manual Analysis': 3, 'CNV/SV': 4}

# Sort the DataFrame by the custom sort order
data_sorted = data_combined.sort_index(key=lambda x: x.map(custom_sort))

colors_list = ['#EC4E20', #flame original
               '#F69A7F', #flame light
               '#FCCCBE', #flame lightest
               '#FF9505', #orange original
               '#FFC474', #orange light
               '#016FB9', #azul original
               '#4799D0', #azul light
               '#8EC4E8', #azul lighter
               '#D4EEFF', #azul lightest
               '#57ABA9', #teal light
               '#C2FCFA'] #teal lightest

# Create a figure with a custom layout using gridspec
# fig = plt.figure(figsize=(6, 8))
# gs = fig.add_gridspec(2, 2, width_ratios=[1, 1], height_ratios=[1, 1])

# Create Waffle plots for each year
fig = plt.figure(
    FigureClass=Waffle,
    plots={
        441: {
            'values': data_sorted.loc[(),'2019'],
            'colors': colors_list,
            'title': {'label': '2019', 'loc': 'left', 'fontsize': 12}
        },
        442: {
            'values': data_sorted.loc[(),'2020'],
            'colors': colors_list,
            'title': {'label': '2020', 'loc': 'left', 'fontsize': 12}
        },
        443: {
            'values': data_sorted.loc[(),'2021'],
            'colors': colors_list,
            'title': {'label': '2021', 'loc': 'left', 'fontsize': 12}
        },
        444: {
            'values': data_sorted.loc[(),'2022'],
            'colors': colors_list,
            'title': {'label': '2022', 'loc': 'left', 'fontsize': 12}
        },
    },
    columns=5,
    values=values,
    vertical=True,
    colors=colors_list,
    rounding_rule='ceil',
    figsize=(12, 12)
)

# Add a main title for the entire figure
fig.suptitle('New Diagnoses by Type and Year', fontsize=14, fontweight='bold')

# Adjust layout to prevent overlap
#plt.tight_layout(rect=[0, 0, 1, 0.95])

# Save the figure
#fig.savefig('../../Figures/Fig5/Fig5_year_cohort.png')

# Show the figure
plt.show()
# Out:
# <Waffle size 1200x1200 with 4 Axes>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle
import matplotlib.patches as mpatches

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
data_combined = data.groupby(level=[0, 1]).sum()

# Custom sort order for the index
custom_sort = {'Gene-disease Associations': 1, 'Variant Reclassifications': 2, 'Missed in Manual Analysis': 3, 'CNV/SV': 4}

# Sort the DataFrame by the custom sort order
data_sorted = data_combined.sort_index(key=lambda x: x.map(custom_sort))

colors_list = ['#EC4E20', #flame original
               '#F69A7F', #flame light
               '#FCCCBE', #flame lightest
               '#FF9505', #orange original
               '#FFC474', #orange light
               '#016FB9', #azul original
               '#4799D0', #azul light
               '#8EC4E8', #azul lighter
               '#D4EEFF', #azul lightest
               '#57ABA9', #teal light
               '#C2FCFA'] #teal lightest


number_of_bars = len(data_sorted.columns) # one bar per year

# Init the whole figure and axes
fig, axs = plt.subplots(nrows=1,
                        ncols=number_of_bars,
                        figsize=(8,6),)

# Iterate over each bar and create it
custom_offset = [0, 0.0455, 0.1155, 0.1155] # height offset for each bar
for i,ax in enumerate(axs):
    l = ax.get_position()
    print(l.width, l.height)
    ax.set_position([(0.25*i), (0.1-custom_offset[i]), l.width, l.height])
    ax.set_aspect('equal')
    col_name = data_sorted.columns[i]
    values = data_sorted[col_name] # values from the i-th column
    
    Waffle.make_waffle(
        ax=ax,  # pass axis to make_waffle 
        #title={"label": col_name, "loc": "left"},
        columns=5,
        values=values,
        vertical=True,
        colors=colors_list,
        rounding_rule='ceil',
        figsize=(5, 5)
    )

ax1 = fig.add_axes([-0.01, 0.13, 0.95, 0.8])
ax1.patch.set_alpha(0)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.yaxis.set_visible(False)

# Set custom x-axis ticks and labels
ax1.set_xticks([0.1, 0.3625, 0.625, 0.8875])
ax1.set_xticklabels(['2019', '2020', '2021', '2022'], fontsize=12)


plt.show()
# Out:
# 0.16847826086956524 0.77
# 0.1684782608695652 0.77
# 0.1684782608695652 0.77
# 0.1684782608695653 0.77

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle
import matplotlib.patches as mpatches

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
data_combined = data.groupby(level=[0, 1]).sum()

# Custom sort order for the index
custom_sort = {'Gene-disease Associations': 4, 'Variant Reclassifications': 3, 'Missed in Manual Analysis': 2, 'CNV/SV': 1}

# Sort the DataFrame by the custom sort order
data_sorted = data_combined.sort_index(key=lambda x: x.map(custom_sort))

colors_list_reversed = [
               '#57ABA9', #teal light
               '#C2FCFA', #teal lightest
               '#016FB9', #azul original
               '#4799D0', #azul light
               '#8EC4E8', #azul lighter
               '#D4EEFF', #azul lightest
               '#FF9505', #orange original
               '#FFC474', #orange light
               '#EC4E20', #flame original
               '#F69A7F', #flame light
               '#FCCCBE'] #flame lightest


number_of_bars = len(data_sorted.columns) # one bar per year

# Init the whole figure and axes
fig, axs = plt.subplots(nrows=1,
                        ncols=number_of_bars,
                        figsize=(8,6),)

# Iterate over each bar and create it
custom_offset = [0, 0.0455, 0.1155, 0.1155] # height offset for each bar
for i,ax in enumerate(axs):
    l = ax.get_position()
    print(l.width, l.height)
    ax.set_position([(0.25*i), (0.1-custom_offset[i]), l.width, l.height])
    ax.set_aspect('equal')
    col_name = data_sorted.columns[i]
    values = data_sorted[col_name] # values from the i-th column
    
    Waffle.make_waffle(
        ax=ax,  # pass axis to make_waffle 
        #title={"label": col_name, "loc": "left"},
        columns=5,
        values=values,
        vertical=True,
        colors=colors_list_reversed,
        rounding_rule='ceil',
        figsize=(5, 5)
    )

ax1 = fig.add_axes([-0.01, 0.13, 0.95, 0.8])
ax1.patch.set_alpha(0)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.yaxis.set_visible(False)

# Set custom x-axis ticks and labels
ax1.set_xticks([0.1, 0.3625, 0.625, 0.8875])
ax1.set_xticklabels(['2019', '2020', '2021', '2022'], fontsize=12)


plt.show()
# Out:
# 0.16847826086956524 0.77
# 0.1684782608695652 0.77
# 0.1684782608695652 0.77
# 0.1684782608695653 0.77

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle
import matplotlib.patches as mpatches

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
data_combined = data.groupby(level=[0, 1]).sum()

# Custom sort order for the index
custom_sort = {'Gene-disease Associations': 4, 'Variant Reclassifications': 3, 'Missed in Manual Analysis': 2, 'CNV/SV': 1}

# Sort the DataFrame by the custom sort order
data_sorted = data_combined.sort_index(key=lambda x: x.map(custom_sort))

colors_list_reversed_flat = [
               '#57ABA9', #teal light
               '#57ABA9', #teal lightest
               '#016FB9', #azul original
               '#016FB9', #azul light
               '#016FB9', #azul lighter
               '#016FB9', #azul lightest
               '#FF9505', #orange original
               '#FF9505', #orange light
               '#EC4E20', #flame original
               '#EC4E20', #flame light
               '#EC4E20'] #flame lightest


number_of_bars = len(data_sorted.columns) # one bar per year

# Init the whole figure and axes
fig, axs = plt.subplots(nrows=1,
                        ncols=number_of_bars,
                        figsize=(8,6),)

# Iterate over each bar and create it
custom_offset = [0, 0.0455, 0.1155, 0.1155] # height offset for each bar
for i,ax in enumerate(axs):
    l = ax.get_position()
    print(l.width, l.height)
    ax.set_position([(0.25*i), (0.1-custom_offset[i]), l.width, l.height])
    ax.set_aspect('equal')
    col_name = data_sorted.columns[i]
    values = data_sorted[col_name] # values from the i-th column
    
    Waffle.make_waffle(
        ax=ax,  # pass axis to make_waffle 
        #title={"label": col_name, "loc": "left"},
        columns=5,
        values=values,
        vertical=True,
        colors=colors_list_reversed_flat,
        rounding_rule='ceil',
        figsize=(5, 5)
    )

ax1 = fig.add_axes([-0.01, 0.13, 0.95, 0.8])
ax1.patch.set_alpha(0)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.yaxis.set_visible(False)





plt.show()
# Out:
# 0.16847826086956524 0.77
# 0.1684782608695652 0.77
# 0.1684782608695652 0.77
# 0.1684782608695653 0.77

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle
import matplotlib.patches as mpatches

plt.rcParams['font.family'] = 'Arial'

# Read the CSV file into a DataFrame
data = pd.read_csv('../../Data/Fig5/Talos_solves_VCGS-prospective-by-year.csv', header=0, index_col=[1, 0], usecols=range(1, 7))

# Combine duplicate rows by summing their values
data_combined = data.groupby(level=[0, 1]).sum()

# Custom sort order for the index
custom_sort = {'New Gene Information': 4, 'New Variant Information': 3, 'Missed in Manual Analysis': 2, 'CNV/SV': 1}

# Sort the DataFrame by the custom sort order
data_sorted = data_combined.sort_index(key=lambda x: x.map(custom_sort))

colors_list_reversed_flat = [
               '#57ABA9', #teal light
               '#57ABA9', 
               '#016FB9', #azul original
               '#016FB9', 
               '#016FB9', 
               '#016FB9', 
               '#FF9505', #orange original
               '#FF9505', 
               '#EC4E20', #flame original
               '#EC4E20', 
               '#EC4E20'] 

colors_list_short = [
               '#57ABA9', #teal light
               '#016FB9', #azul original
               '#FF9505', #orange original
               '#EC4E20'] #flame original


number_of_bars = len(data_sorted.columns) # one bar per year

# Init the whole figure and axes
fig, axs = plt.subplots(nrows=1,
                        ncols=number_of_bars,
                        figsize=(8,6),)

# Iterate over each bar and create it
custom_offset = [0, 0.0455, 0.1155, 0.1155] # height offset for each bar
for i,ax in enumerate(axs):
    l = ax.get_position()
    ax.set_position([(0.25*i), (0.1-custom_offset[i]), l.width, l.height])
    ax.set_aspect('equal')
    col_name = data_sorted.columns[i]
    values = data_sorted[col_name] # values from the i-th column
    
    Waffle.make_waffle(
        ax=ax,  # pass axis to make_waffle 
        #title={"label": col_name, "loc": "left"},
        columns=5,
        values=values,
        vertical=True,
        colors=colors_list_reversed_flat,
        rounding_rule='ceil',
        figsize=(5, 5)
    )

ax1 = fig.add_axes([-0.01, 0.13, 0.95, 0.8])
ax1.patch.set_alpha(0)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.yaxis.set_visible(False)

# Create legend for colors
patches = []
for x in range(len((data_sorted.index.get_level_values(0)).unique())):
    labels = list((data_sorted.index.get_level_values(0)).unique())
    patches.append(mpatches.Patch(color=colors_list_short[x], label=labels[x]))
plt.legend(handles=patches, bbox_to_anchor=(3,2), loc="lower left")

legend1 = plt.legend(handles=patches, loc="upper right", fontsize=12)
fig.add_artist(legend1)

# # Create an additional legend explaining 1 block = 1 case
# b2=ax1.plot([], marker="s", markersize=16, linestyle="", color="gray",  label="1 block equals 1 case")
# ax1.legend(handles=b2, frameon=False, fontsize=12, loc="upper right", bbox_to_anchor=(1, 0.78))

# Set custom x-axis ticks and labels
ax1.set_xticks([0.098, 0.36, 0.625, 0.89, 1])
ax1.set_xticklabels(['2019\n8.1% Diagnostic yield\n71/879 cases', '2020\n6.1% Diagnostic yield\n65/1071 cases',
                      '2021\n3.5% Diagnostic yield\n46/1321 cases', '2022\n3.7% Diagnostic yield\n46/1236 cases', ''], fontsize=12)
ax1.set_xlabel('Year of initial analysis', fontsize=16)
ax1.set_ylabel('Count', fontsize=14)

fig.savefig('../../Figures/Fig5/Fig5_year_cohort_Bar.png', bbox_inches='tight')
plt.show()
