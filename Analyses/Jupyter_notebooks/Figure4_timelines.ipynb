# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle, FancyBboxPatch

plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.it'] = 'STIXGeneral:italic'
plt.rcParams['mathtext.bf'] = 'STIXGeneral:italic:bold'
plt.rcParams['text.usetex'] = False
#plt.rcParams['text.usetex'] = True

ax_font_size = "x-large"
annotation_font_size = "large"
case_description_font_size = "x-large"
point_border_width = 1.5
point_size = 100

# Annotation Style borrowed from:
# "Scientific Visualisation - Python & Matplotlib" by Nicolas P. Rougier
# BSD License
def annotate(ax, x, y, text, fc="#016FB9", y0=0):
    y = y - 0.5
    ax.annotate(
        " " + text + " ",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="white",
        size=annotation_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="round", fc=fc, ec="none"),
        arrowprops=dict(
            arrowstyle="wedge,tail_width=1.5", fc=fc, ec="none", patchA=None
        ),
    )
    plt.plot([x, x], [y, y0], color="black", linestyle=":", linewidth=0.75)

def case_description(ax, x, y, text, fc="white", y0=0):
    ax.annotate(
        "\n " + text + " \n",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="#016FB9",
        size=case_description_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="rarrow", fc=fc, ec="#016FB9", lw=2, pad=0.5),
    )

# Create a figure with a custom layout using gridspec
fig = plt.figure(figsize=(12, 6))
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1])

#Generate timeline 0
ax0 = fig.add_subplot(gs[0], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax0.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 0
X = [2021.42, 2021.44, 2021.48, 2022.7, 2023.5, 2023.64, 2023.68, 2023.99]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

# #pseudo-legend using annotations
# annotate(ax0, 2019.2, 5, "Event allowing detection", y0=5.2, fc="#F2805F")
# annotate(ax0, 2019.2, 3.5, " Date identified by Talos ", y0=3.7, fc="#EC4E20")

# # Draw a box around legend boxes
# rect = mpatches.FancyBboxPatch((0.007, 0.45), 0.187, 0.45, linewidth=1, edgecolor='lightgray', facecolor='none', transform=plt.gca().transAxes, boxstyle='Round, pad=0.005', mutation_aspect=8)
# plt.gca().add_patch(rect)

case_description(ax0, 2018, 3, "Patient 1")
annotate(ax0, 2021.42, 5.5, "Birth of Patient")
annotate(ax0, 2021.44, 4, "NICU Admission")
annotate(ax0, 2021.48, 2.5, "WGS - No Diagnosis")
annotate(ax0, 2022.7, 6.8, "Enters Reanalysis Program")
annotate(ax0, 2023.5, 5.3, "$\mathbf{KCNA3}$ presented at ESHG", fc='#F2805F')
annotate(ax0, 2023.64, 3.8, "$\mathbf{KCNA3}$ added to PanelAppAus", fc='#F2805F')
annotate(ax0, 2023.68, 2.3, "Talos Diagnosis", fc="#EC4E20")
annotate(ax0, 2023.99, .8, "$\mathbf{KCNA3}$ published")

ax0.spines["right"].set_visible(False)
ax0.spines["left"].set_visible(False)
ax0.spines["top"].set_visible(False)
ax0.spines["bottom"].set_visible(False)
ax0.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 1
ax1 = fig.add_subplot(gs[1], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax1.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2020.05,2020.4,2024.17, 2024.33, 2024.38, 2024.40]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax1, 2018, 3, "Patient 2")
annotate(ax1, 2020.05, 5, "WGS Initiated")
annotate(ax1, 2020.4, 2.5, "WGS - No Diagnosis")
annotate(ax1, 2024.17, 5.5, "Enters Reanalysis Program")
annotate(ax1, 2024.33, 4, "$\mathbf{RNU4‒2}$ preprint available", fc='#F2805F')
annotate(ax1, 2024.38, 2.5, "$\mathbf{RNU4‒2}$ added to PanelAppAus", fc='#F2805F')
annotate(ax1, 2024.40, 1, "Talos Diagnosis", fc="#EC4E20")

ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 2
ax2 = fig.add_subplot(gs[2], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax2.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2019.8, 2019.95, 2023.6, 2023.95, 2024.17]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax2, 2018, 3, "Patient 3")
annotate(ax2, 2019.8, 5, "WGS Initiated")
annotate(ax2, 2019.95, 1.85, "", y0=2) # Add a blank annotation to make the pointer complete
annotate(ax2, 2019.95, 2.5, "WGS - No Diagnosis\n $\mathbf{ALPK3}$: pathogenic,\nsingle variant in AR gene")
annotate(ax2, 2023.6, 5, "Enters Reanalysis Program")
annotate(ax2, 2023.95, 3, "ClinGen $\mathbf{ALPK3}$ updated\nAD Association \'Strong\'", fc='#F2805F')
annotate(ax2, 2024.17, 1, "Talos Diagnosis", fc="#EC4E20")

ax2.spines["right"].set_visible(False)
ax2.spines["left"].set_visible(False)
ax2.spines["top"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.set_xticks(np.arange(2019, 2026, 1))

# Show and save the plot
plt.tight_layout()
plt.savefig('../../Figures/Fig4/Fig4_timelines_arrow.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle, FancyBboxPatch

plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.it'] = 'STIXGeneral:italic'
plt.rcParams['mathtext.bf'] = 'STIXGeneral:italic:bold'
plt.rcParams['text.usetex'] = False
#plt.rcParams['text.usetex'] = True

ax_font_size = "x-large"
annotation_font_size = "large"
case_description_font_size = "x-large"
point_border_width = 1.5
point_size = 100

# Annotation Style borrowed from:
# "Scientific Visualisation - Python & Matplotlib" by Nicolas P. Rougier
# BSD License
def annotate(ax, x, y, text, fc="#016FB9", y0=0):
    y = y - 0.5
    ax.annotate(
        " " + text + " ",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="white",
        size=annotation_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="round", fc=fc, ec="none"),
        arrowprops=dict(
            arrowstyle="wedge,tail_width=1.5", fc=fc, ec="none", patchA=None
        ),
    )
    plt.plot([x, x], [y, y0], color="black", linestyle=":", linewidth=0.75)

def case_description(ax, x, y, text, fc="white", y0=0):
    ax.annotate(
        " " + text + " ",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="#016FB9",
        size=case_description_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="round", fc=fc, ec="#016FB9", lw=2, pad=0.3),
    )

# Create a figure with a custom layout using gridspec
fig = plt.figure(figsize=(12, 6))
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1])

#Generate timeline 0
ax0 = fig.add_subplot(gs[0], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax0.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 0
X = [2021.42, 2021.44, 2021.48, 2022.7, 2023.5, 2023.64, 2023.68, 2023.99]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

# #pseudo-legend using annotations
# annotate(ax0, 2019.2, 5, "Event allowing detection", y0=5.2, fc="#F2805F")
# annotate(ax0, 2019.2, 3.5, " Date identified by Talos ", y0=3.7, fc="#EC4E20")

# # Draw a box around legend boxes
# rect = mpatches.FancyBboxPatch((0.007, 0.45), 0.187, 0.45, linewidth=1, edgecolor='lightgray', facecolor='none', transform=plt.gca().transAxes, boxstyle='Round, pad=0.005', mutation_aspect=8)
# plt.gca().add_patch(rect)

case_description(ax0, 2018, 3, "Patient 1")
annotate(ax0, 2021.42, 5.5, "Birth of Patient")
annotate(ax0, 2021.44, 4, "NICU Admission")
annotate(ax0, 2021.48, 2.5, "WGS - No Diagnosis")
annotate(ax0, 2022.7, 6.8, "Enters Reanalysis Program")
annotate(ax0, 2023.5, 5.3, "$\mathbf{KCNA3}$ presented at ESHG", fc='#F2805F')
annotate(ax0, 2023.64, 3.8, "$\mathbf{KCNA3}$ added to PanelAppAus", fc='#F2805F')
annotate(ax0, 2023.68, 2.3, "Talos Diagnosis", fc="#EC4E20")
annotate(ax0, 2023.99, .8, "$\mathbf{KCNA3}$ published")

ax0.spines["right"].set_visible(False)
ax0.spines["left"].set_visible(False)
ax0.spines["top"].set_visible(False)
ax0.spines["bottom"].set_visible(False)
ax0.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 1
ax1 = fig.add_subplot(gs[1], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax1.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2020.05,2020.4,2024.17, 2024.33, 2024.38, 2024.40]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax1, 2018, 3, "Patient 2")
annotate(ax1, 2020.05, 5, "WGS Initiated")
annotate(ax1, 2020.4, 2.5, "WGS - No Diagnosis")
annotate(ax1, 2024.17, 5.5, "Enters Reanalysis Program")
annotate(ax1, 2024.33, 4, "$\mathbf{RNU4‒2}$ preprint available", fc='#F2805F')
annotate(ax1, 2024.38, 2.5, "$\mathbf{RNU4‒2}$ added to PanelAppAus", fc='#F2805F')
annotate(ax1, 2024.40, 1, "Talos Diagnosis", fc="#EC4E20")

ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 2
ax2 = fig.add_subplot(gs[2], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax2.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2019.8, 2019.95, 2023.6, 2023.95, 2024.17]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax2, 2018, 3, "Patient 3")
annotate(ax2, 2019.8, 5, "WGS Initiated")
annotate(ax2, 2019.95, 1.85, "", y0=2) # Add a blank annotation to make the pointer complete
annotate(ax2, 2019.95, 2.5, "WGS - No Diagnosis\n $\mathbf{ALPK3}$: pathogenic,\nsingle variant in AR gene")
annotate(ax2, 2023.6, 5, "Enters Reanalysis Program")
annotate(ax2, 2023.95, 3, "ClinGen $\mathbf{ALPK3}$ updated\nAD Association \'Strong\'", fc='#F2805F')
annotate(ax2, 2024.17, 1, "Talos Diagnosis", fc="#EC4E20")

ax2.spines["right"].set_visible(False)
ax2.spines["left"].set_visible(False)
ax2.spines["top"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.set_xticks(np.arange(2019, 2026, 1))

# Show and save the plot
plt.tight_layout()
plt.savefig('../../Figures/Fig4/Fig4_timelines_rbox.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle, FancyBboxPatch

plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.it'] = 'STIXGeneral:italic'
plt.rcParams['mathtext.bf'] = 'STIXGeneral:italic:bold'
plt.rcParams['text.usetex'] = False
#plt.rcParams['text.usetex'] = True

ax_font_size = "x-large"
annotation_font_size = "large"
case_description_font_size = "x-large"
point_border_width = 1.5
point_size = 100

# Annotation Style borrowed from:
# "Scientific Visualisation - Python & Matplotlib" by Nicolas P. Rougier
# BSD License
def annotate(ax, x, y, text, fc="#016FB9", y0=0):
    y = y - 0.5
    ax.annotate(
        " " + text + " ",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="white",
        size=annotation_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="round", fc=fc, ec="none"),
        arrowprops=dict(
            arrowstyle="wedge,tail_width=1.5", fc=fc, ec="none", patchA=None
        ),
    )
    plt.plot([x, x], [y, y0], color="black", linestyle=":", linewidth=0.75)

def case_description(ax, x, y, text, fc="white", y0=0):
    ax.annotate(
        "\n " + text + " \n",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="#016FB9",
        size=case_description_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="round", fc=fc, ec="#016FB9", lw=2, pad=0.5),
    )

# Create a figure with a custom layout using gridspec
fig = plt.figure(figsize=(12, 9))
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1])

#Generate timeline 0
ax0 = fig.add_subplot(gs[0], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax0.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 0
X = [2021.42, 2021.44, 2021.48, 2022.7, 2023.5, 2023.64, 2023.68, 2023.99]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

# #pseudo-legend using annotations
# annotate(ax0, 2019.2, 5, "Event allowing detection", y0=5.2, fc="#F2805F")
# annotate(ax0, 2019.2, 3.5, " Date identified by Talos ", y0=3.7, fc="#EC4E20")

# # Draw a box around legend boxes
# rect = mpatches.FancyBboxPatch((0.007, 0.45), 0.187, 0.45, linewidth=1, edgecolor='lightgray', facecolor='none', transform=plt.gca().transAxes, boxstyle='Round, pad=0.005', mutation_aspect=8)
# plt.gca().add_patch(rect)

case_description(ax0, 2018, 2, "Patient 1")
annotate(ax0, 2021.42, 4, "Birth of Patient")
annotate(ax0, 2021.44, 3, "NICU Admission")
annotate(ax0, 2021.48, 2, "WGS - No Diagnosis")
annotate(ax0, 2022.7, 5, "Enters Reanalysis Program")
annotate(ax0, 2023.5, 4, "$\mathbf{KCNA3}$ presented at ESHG", fc='#F2805F')
annotate(ax0, 2023.64, 3, "$\mathbf{KCNA3}$ added to PanelAppAus", fc='#F2805F')
annotate(ax0, 2023.68, 2, "Talos Diagnosis", fc="#EC4E20")
annotate(ax0, 2023.99, 1, "$\mathbf{KCNA3}$ published")

ax0.spines["right"].set_visible(False)
ax0.spines["left"].set_visible(False)
ax0.spines["top"].set_visible(False)
ax0.spines["bottom"].set_visible(False)
ax0.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 1
ax1 = fig.add_subplot(gs[1], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax1.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2020.05,2020.4,2024.17, 2024.33, 2024.38, 2024.40]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax1, 2018, 2, "Patient 2")
annotate(ax1, 2020.05, 3.5, "WGS Initiated")
annotate(ax1, 2020.4, 1.5, "WGS - No Diagnosis")
annotate(ax1, 2024.17, 4, "Enters Reanalysis Program")
annotate(ax1, 2024.33, 3, "$\mathbf{RNU4‒2}$ preprint available", fc='#F2805F')
annotate(ax1, 2024.38, 2, "$\mathbf{RNU4‒2}$ added to PanelAppAus", fc='#F2805F')
annotate(ax1, 2024.40, 1, "Talos Diagnosis", fc="#EC4E20")

ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 2
ax2 = fig.add_subplot(gs[2], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax2.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2019.8, 2019.95, 2023.6, 2023.95, 2024.17]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax2, 2018, 2, "Patient 3")
annotate(ax2, 2019.8, 3.5, "WGS Initiated")
annotate(ax2, 2019.95, 1.5, "", y0=2) # Add a blank annotation to make the pointer complete
annotate(ax2, 2019.95, 2, "WGS - No Diagnosis\n $\mathbf{ALPK3}$: pathogenic,\nsingle variant in AR gene")
annotate(ax2, 2023.6, 4, "Enters Reanalysis Program")
annotate(ax2, 2023.95, 2.5, "ClinGen $\mathbf{ALPK3}$ updated\nAD Association \'Strong\'", fc='#F2805F')
annotate(ax2, 2024.17, 1, "Talos Diagnosis", fc="#EC4E20")

ax2.spines["right"].set_visible(False)
ax2.spines["left"].set_visible(False)
ax2.spines["top"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.set_xticks(np.arange(2019, 2026, 1))

# Show and save the plot
plt.tight_layout()
plt.savefig('../../Figures/Fig4/Fig4_timelines_rbox_larger_space.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle, FancyBboxPatch

plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.it'] = 'STIXGeneral:italic'
plt.rcParams['mathtext.bf'] = 'STIXGeneral:italic:bold'
plt.rcParams['text.usetex'] = False
#plt.rcParams['text.usetex'] = True

ax_font_size = "x-large"
annotation_font_size = "large"
case_description_font_size = "x-large"
point_border_width = 1.5
point_size = 100

# Annotation Style borrowed from:
# "Scientific Visualisation - Python & Matplotlib" by Nicolas P. Rougier
# BSD License
def annotate(ax, x, y, text, fc="#016FB9", y0=0):
    y = y - 0.5
    ax.annotate(
        " " + text + " ",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="white",
        size=annotation_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="round", fc=fc, ec="none"),
        arrowprops=dict(
            arrowstyle="wedge,tail_width=1.5", fc=fc, ec="none", patchA=None
        ),
    )
    plt.plot([x, x], [y, y0], color="black", linestyle=":", linewidth=0.75)

def case_description(ax, x, y, text, fc="white", y0=0):
    ax.annotate(
        "\n " + text + " \n",
        xy=(x, y),
        xycoords="data",
        xytext=(0, 12),
        textcoords="offset points",
        color="#016FB9",
        size=case_description_font_size,
        va="center",
        ha="center",
        weight="bold",
        bbox=dict(boxstyle="round", fc=fc, ec="#016FB9", lw=2, pad=0.5),
    )

# Create a figure with a custom layout using gridspec
fig = plt.figure(figsize=(12, 6))
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1])

#Generate timeline 0
ax0 = fig.add_subplot(gs[0], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax0.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 0
X = [2021.42, 2021.44, 2021.48, 2022.7, 2023.5, 2023.64, 2023.68, 2023.99]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

# #pseudo-legend using annotations
# annotate(ax0, 2019.2, 5, "Event allowing detection", y0=5.2, fc="#F2805F")
# annotate(ax0, 2019.2, 3.5, " Date identified by Talos ", y0=3.7, fc="#EC4E20")

# # Draw a box around legend boxes
# rect = mpatches.FancyBboxPatch((0.007, 0.45), 0.187, 0.45, linewidth=1, edgecolor='lightgray', facecolor='none', transform=plt.gca().transAxes, boxstyle='Round, pad=0.005', mutation_aspect=8)
# plt.gca().add_patch(rect)

case_description(ax0, 2018, 3, "Patient 1:\n Admitted 2021 \n Reanalysis 2022 \n Solved 2023")
annotate(ax0, 2021.42, 5.5, "Birth of Patient")
annotate(ax0, 2021.44, 4, "NICU Admission")
annotate(ax0, 2021.48, 2.5, "WGS - No Diagnosis")
annotate(ax0, 2022.7, 6.8, "Enters Reanalysis Program")
annotate(ax0, 2023.5, 5.3, "$\mathbf{KCNA3}$ presented at ESHG", fc='#F2805F')
annotate(ax0, 2023.64, 3.8, "$\mathbf{KCNA3}$ added to PanelAppAus", fc='#F2805F')
annotate(ax0, 2023.68, 2.3, "Talos Diagnosis", fc="#EC4E20")
annotate(ax0, 2023.99, .8, "$\mathbf{KCNA3}$ published")

ax0.spines["right"].set_visible(False)
ax0.spines["left"].set_visible(False)
ax0.spines["top"].set_visible(False)
ax0.spines["bottom"].set_visible(False)
ax0.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 1
ax1 = fig.add_subplot(gs[1], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax1.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2020.05,2020.4,2024.17, 2024.33, 2024.38, 2024.40]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax1, 2018, 3, "Patient 2:\n Admitted 2020 \n Reanalysis 2024 \n Solved 2024")
annotate(ax1, 2020.05, 5, "WGS Initiated")
annotate(ax1, 2020.4, 2.5, "WGS - No Diagnosis")
annotate(ax1, 2024.17, 5.5, "Enters Reanalysis Program")
annotate(ax1, 2024.33, 4, "$\mathbf{RNU4‒2}$ preprint available", fc='#F2805F')
annotate(ax1, 2024.38, 2.5, "$\mathbf{RNU4‒2}$ added to PanelAppAus", fc='#F2805F')
annotate(ax1, 2024.40, 1, "Talos Diagnosis", fc="#EC4E20")

ax1.spines["right"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.set_xticks(np.arange(2019, 2026, 1))

#Generate timeline 2
ax2 = fig.add_subplot(gs[2], xlim=(2017.5, 2025.2), ylim=(0, 6.5), yticks=([]))
ax2.tick_params("x", labelsize=ax_font_size, which="major")
plt.plot([2018.8, 2025.2], [0, 0], color="black", linewidth=1.0, clip_on=False)

# Add points to timeline 1
X = [2019.8, 2019.95, 2023.6, 2023.95, 2024.17]
Y = np.zeros(len(X))
plt.scatter(
    X,
    Y,
    s=point_size,
    linewidth=point_border_width,
    zorder=10,
    clip_on=False,
    edgecolor="#016FB9",
    facecolor="white",
)

case_description(ax2, 2018, 3, "Patient 3:\n Admitted 2019 \n Reanalysis 2023 \n Solved 2024")
annotate(ax2, 2019.8, 5, "WGS Initiated")
annotate(ax2, 2019.95, 1.85, "", y0=2) # Add a blank annotation to make the pointer complete
annotate(ax2, 2019.95, 2.5, "WGS - No Diagnosis\n $\mathbf{ALPK3}$: pathogenic,\nsingle variant in AR gene")
annotate(ax2, 2023.6, 5, "Enters Reanalysis Program")
annotate(ax2, 2023.95, 3, "ClinGen $\mathbf{ALPK3}$ updated\nAD Association \'Strong\'", fc='#F2805F')
annotate(ax2, 2024.17, 1, "Talos Diagnosis", fc="#EC4E20")

ax2.spines["right"].set_visible(False)
ax2.spines["left"].set_visible(False)
ax2.spines["top"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.set_xticks(np.arange(2019, 2026, 1))

# Show and save the plot
plt.tight_layout()
plt.savefig('../../Figures/Fig4/Fig4_timelines_rbox_desc.png')
plt.show()
